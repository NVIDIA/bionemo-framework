# %% [markdown]
# ## Fine-tuning tutorial for Evo2: Adapt the 1b evo2 checkpoint for your hardware
# Deploy tutorial on brev.dev:
# [![ Click here to deploy.](https://brev-assets.s3.us-west-1.amazonaws.com/nv-lb-dark.svg)](https://console.brev.dev/launchable/deploy?launchableID=env-2uGqijcTiNxv3V8LZJxXAa7KlKC)
#
# ### Background and motivation
# To motivate this tutorial, we have noticed that the public
# evo2 checkpoint in hugging face for the 1b model is sensitive to `--fp8` status in training, the zero shot inference
# task, as demonstrated in the zero shot BRCA-1 notebook, produces near random AUCs if you do not use `--fp8`.
# If you want to infer or score new data, you need FP8 enabled since it was trained that way. Interestingly the `7b` checkpoint does not suffer from this
# limitation and seems robust to FP8 being activated or not. The consequence of this is that if you have older GPUs with
# a compute capability less than 8.9, which do not support FP8, then the output that you get from scoring sequences with
# sensitive checkpoints may not be biologically meaningful.
#
# We plan on making
# a `1b` parameter evo2 checkpoint available soon that has been fine-tuned to be robust to FP8 or BF16 inference in bionemo
# on NGC, but in the meantime this notebook tutorial outlines the steps for fine-tuning. The only difference between this
# notebook and what we did in production was to run these steps on more data on a slurm cluster to increase the global
# batch size. That said, if you run this for enough steps to get loss on the 1b checkpoint to the 1.08 range, you should
# have good luck with downstream sequence scoring tasks.
#
# ### Requirements
#
# This is a tutorial demonstrating how you can fine-tune Evo2 on new data and/or hardware. The tutorial should take
# slightly under 1 hour to run on an RTX A6000 in bf16 precision.
#
# As configured, this tutorial requires an NVIDIA GPU with approximately 45GB of ram. If you have multiple GPUs with less
# memory, or you are having trouble with CUDA OOM at the training step below, try reducing the `--micro-batch-size` and/or
# increasing the number of `--devices [int]` to match your setup and also setting `--tensor-parallel-size [int]` to
# the number of devices. This should split up most of the model evenly between your devices, which will require much less
# memory. When we train the 1b model in practice we typically have the micro batch size set to 8, and run without model
# parallelism on available devices to achieve the largest possible global batch size.

# %%
import os


# This variable should be used in the notebooks to run a subset of the model layers or a smaller model/dataset
FAST_CI_MODE: bool = os.environ.get("FAST_CI_MODE", False)
# Clean up any prior runs
CLEANUP: bool = False
if CLEANUP:
    # !rm -rf preprocessed_data
    # !rm -rf preatraining_demo
    # !rm -rf pretraining_demo
    # !rm -rf training_data_config.yaml
    # !rm -rf preprocess_config.yaml
    # !rm -f chr20.fa.gz
    # !rm -f chr21.fa.gz
    # !rm -f chr22.fa.gz
    # !rm -f chr20_21_22.fa

# %% [markdown]
# ### Setup training data
# Evo2 uses megatron style datasets behind the scenes with advanced support for randomly indexing into documents, and
# packing documents together into batches at scale. The file-formats backing these datasets is not a standard biological
# format like fasta for representing genomes. First we show how you can start from a fasta file and preprocess them into
# the required data format for downstream handling. High level the steps are as follows:
# 1. Acquire fasta files locally, ideally in some shared cluster storage
# 2. Write a config script defining how you want the processed files to be generated from the fasta files. This is where
#   you specify top level train/validation/test splitting decisions.
# 3. Call the actual `preprocess_evo2` script to generate the results.
#
# The next 4 cells go through this process on a set of smaller human chromosomes. At least 3 fasta records need to be present,
# one for the train, validation, and test split.

# %%
###%%capture
import os


concat_path = "chr20_21_22.fa"
if not os.path.exists(concat_path):
    # !wget https://hgdownload.soe.ucsc.edu/goldenpath/hg38/chromosomes/chr20.fa.gz
    # !wget https://hgdownload.soe.ucsc.edu/goldenpath/hg38/chromosomes/chr21.fa.gz
    # !wget https://hgdownload.soe.ucsc.edu/goldenpath/hg38/chromosomes/chr22.fa.gz
    # !zcat chr20.fa.gz > chr20.fa
    # !zcat chr21.fa.gz > chr21.fa
    # !zcat chr22.fa.gz > chr22.fa
    # !cat chr20.fa chr21.fa chr22.fa > chr20_21_22.fa
# Out:
# --2025-06-23 17:46:21--  https://hgdownload.soe.ucsc.edu/goldenpath/hg38/chromosomes/chr20.fa.gz
# Resolving hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)|128.114.119.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20350590 (19M) [application/x-gzip]
# Saving to: ‘chr20.fa.gz’
#
# chr20.fa.gz         100%[===================>]  19.41M  50.1MB/s    in 0.4s
#
# 2025-06-23 17:46:22 (50.1 MB/s) - ‘chr20.fa.gz’ saved [20350590/20350590]
#
# --2025-06-23 17:46:23--  https://hgdownload.soe.ucsc.edu/goldenpath/hg38/chromosomes/chr21.fa.gz
# Resolving hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)|128.114.119.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12709705 (12M) [application/x-gzip]
# Saving to: ‘chr21.fa.gz’
#
# chr21.fa.gz         100%[===================>]  12.12M  30.7MB/s    in 0.4s
#
# 2025-06-23 17:46:23 (30.7 MB/s) - ‘chr21.fa.gz’ saved [12709705/12709705]
#
# --2025-06-23 17:46:24--  https://hgdownload.soe.ucsc.edu/goldenpath/hg38/chromosomes/chr22.fa.gz
# Resolving hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)|128.114.119.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12255678 (12M) [application/x-gzip]
# Saving to: ‘chr22.fa.gz’
#
# chr22.fa.gz         100%[===================>]  11.69M  37.3MB/s    in 0.3s
#
# 2025-06-23 17:46:24 (37.3 MB/s) - ‘chr22.fa.gz’ saved [12255678/12255678]

# %%
full_fasta_path = os.path.abspath(concat_path)
output_dir = os.path.abspath("preprocessed_data")
output_yaml = f"""
- datapaths: ["{full_fasta_path}"]
  output_dir: "{output_dir}"
  output_prefix: chr20_21_22_uint8_distinct
  train_split: 0.9
  valid_split: 0.05
  test_split: 0.05
  overwrite: True
  embed_reverse_complement: true
  random_reverse_complement: 0.0
  random_lineage_dropout: 0.0
  include_sequence_id: false
  transcribe: "back_transcribe"
  force_uppercase: false
  indexed_dataset_dtype: "uint8"
  tokenizer_type: "Byte-Level"
  vocab_file: null
  vocab_size: null
  merges_file: null
  pretrained_tokenizer_model: null
  special_tokens: null
  fast_hf_tokenizer: true
  append_eod: true
  enforce_sample_length: null
  ftfy: false
  workers: 1
  preproc_concurrency: 100000
  chunksize: 25
  drop_empty_sequences: true
  nnn_filter: false  # If you split your fasta on NNN (in human these are contigs), then you should set this to true.
  seed: 12342  # Not relevant because we are not using random reverse complement or lineage dropout.
"""
with open("preprocess_config.yaml", "w") as f:
    print(output_yaml, file=f)

# %%
##%%capture
# !preprocess_evo2 --config preprocess_config.yaml
# Out:
# [NeMo I 2025-06-23 17:46:53 nemo_logging:393] Using byte-level tokenization
# [NeMo I 2025-06-23 17:46:54 nemo_logging:393] Created temporary binary datasets: /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_train.bin.tmp /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_val.bin.tmp /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_test.bin.tmp
# [NeMo I 2025-06-23 17:47:21 nemo_logging:393] Average preprocessing time per sequence: 0.9026958147684733
# [NeMo I 2025-06-23 17:47:21 nemo_logging:393] Average indexing time per sequence: 3.798583229382833
# [NeMo I 2025-06-23 17:47:21 nemo_logging:393] Number of sequences processed: 6
# [NeMo I 2025-06-23 17:47:22 nemo_logging:393] Finished preprocessing chr20_21_22_uint8_distinct ([PosixPath('/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/chr20_21_22.fa')]) in 28.032 seconds with 1 workers.

# %%
# There should be a collection of bin/idx files created in the preprocessed_data directory.
# !ls -lh preprocessed_data/
# Out:
# total 309M
# -rw-r--r-- 1 ubuntu ubuntu  97M Jun 23 17:47 chr20_21_22_uint8_distinct_byte-level_test.bin
# -rw-r--r-- 1 ubuntu ubuntu   82 Jun 23 17:47 chr20_21_22_uint8_distinct_byte-level_test.idx
# -rw-r--r-- 1 ubuntu ubuntu  90M Jun 23 17:47 chr20_21_22_uint8_distinct_byte-level_train.bin
# -rw-r--r-- 1 ubuntu ubuntu   82 Jun 23 17:47 chr20_21_22_uint8_distinct_byte-level_train.idx
# -rw-r--r-- 1 ubuntu ubuntu 123M Jun 23 17:47 chr20_21_22_uint8_distinct_byte-level_val.bin
# -rw-r--r-- 1 ubuntu ubuntu   82 Jun 23 17:47 chr20_21_22_uint8_distinct_byte-level_val.idx

# %% [markdown]
# ### [Optional] specify or convert initial checkpoint
# The main difference between pre-training and fine-tuning is whether or not you decide to start training the model with
# weights from a prior training run. For this tutorial we want to tune a `1b` checkpoint from hugging face that is known
# (at the time of this writing) to be sensitive to GPU architecture so that it will work with your architecture. We have a
# script that will download and convert a savanna format evo2 checkpoint from hugging face, and output that into a NeMo2
# format checkpoint directory that can be used as the starting point for a fine-tuning run.

# %%
##%%capture
if not os.path.exists("nemo2_evo2_1b_8k"):
    # !evo2_convert_to_nemo2 \
      --model-path hf://arcinstitute/savanna_evo2_1b_base \
      --model-size 1b --output-dir nemo2_evo2_1b_8k
# Out:
# Could not find the bitsandbytes CUDA binary at PosixPath('/usr/local/lib/python3.12/dist-packages/bitsandbytes/libbitsandbytes_cuda129.so')
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Using byte-level tokenization
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [NeMo W 2025-06-23 17:47:46 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
#
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Fixing mis-match between ddp-config & mcore-optimizer config
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has data parallel group : [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has combined group of data parallel and context parallel : [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] All data parallel group ranks with context parallel combined: [[0]]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Ranks 0 has data parallel rank: 0
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has context parallel group: [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] All context parallel group ranks: [[0]]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Ranks 0 has context parallel rank: 0
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has model parallel group: [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] All model parallel group ranks: [[0]]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has tensor model parallel group: [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] All tensor model parallel group ranks: [[0]]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has pipeline model parallel group: [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has embedding group: [0]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] All pipeline model parallel group ranks: [[0]]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] All embedding group ranks: [[0]]
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Rank 0 has embedding rank: 0
# ----------------------------------------------------------------------------------------------------
# distributed_backend=gloo
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# [NeMo W 2025-06-23 17:47:46 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py:1090: `trainer.init_module` cannot fully support proper instantiation of your model with the `MegatronStrategy` strategy. Please instantiate your model inside the`LightningModule.configure_model` hook instead
#
# [NeMo I 2025-06-23 17:47:46 nemo_logging:393] Padded vocab_size: 512, original vocab_size: 512, dummy tokens: 0.
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-23 17:47:47 nemo_logging:405] Could not copy Trainer's 'max_steps' to LR scheduler's 'max_steps'. If you are not using an LR scheduler, this warning can safely be ignored.
# [NeMo I 2025-06-23 17:47:47 nemo_logging:393] Using FullyParallelSaveStrategyWrapper(torch_dist, 1) dist-ckpt save strategy.
# [NeMo I 2025-06-23 17:47:52 nemo_logging:393] Global Checkpoint Save : Rank: 0 : Iteration: 0 : Start time: 1750700867.796s : Save duration: 4.513s
# [NeMo I 2025-06-23 17:47:52 nemo_logging:393] Converted Hyena model to Nemo, model saved to nemo2_evo2_1b_8k

# %% [markdown]
# ### Configure the training dataset
# The next step is to configure your training dataset, in this case configuring the simple single-file example we output
# two steps ago in this tutorial.

# %%
from pathlib import Path


output_pfx = str(Path(os.path.abspath("preprocessed_data")) / "chr20_21_22_uint8_distinct_byte-level")
output_yaml = f"""
- dataset_prefix: {output_pfx}_train
  dataset_split: train
  dataset_weight: 1.0
- dataset_prefix: {output_pfx}_val
  dataset_split: validation
  dataset_weight: 1.0
- dataset_prefix: {output_pfx}_test
  dataset_split: test
  dataset_weight: 1.0
"""
with open("training_data_config.yaml", "w") as f:
    print(output_yaml, file=f)

# %% [markdown]
# This next cell takes approximately 25 minutes to run on an RTX A6000 with `MAX_STEPS=100`. Each step takes about 9.5 seconds with the
# following configuration, so you can budget a desired number of max steps to try.

# %%
##%%capture
! rm -rf pretraining_demo
MAX_STEPS: int = 10 if FAST_CI_MODE else 100
val_check_interval = min(int(MAX_STEPS // 2), 50)
warmup_steps = min(MAX_STEPS, 100)
# For evo2 training and fine-tuning follow the same set of steps, so we use the same train_evo2 command.
#  the big difference is the --ckpt-dir argument which points to a pre-existing checkpoint from some other training run.
model_size = "1b"
if FAST_CI_MODE:
    model_subset_option = (
        "--num-layers 4 --hybrid-override-pattern SDH* --activation-checkpoint-recompute-num-layers 2"
    )
elif model_size == "1b":
    # By default do 5 layers of activation checkpointing
    model_subset_option = "--activation-checkpoint-recompute-num-layers 5" # this need to be evenly divisible by the number of layers in the model. We can just disable it using --no-activation-checkpointing
elif model_size == "7b":
    model_subset_option = "--activation-checkpoint-recompute-num-layers 4" # this need to be evenly divisible by the number of layers in the model. We can just disable it using --no-activation-checkpointing
    # model_subset_option = "--no-activation-checkpointing"
else:
    raise ValueError(f"Model size {model_size} not supported")
   
train_cmd = f"""train_evo2 \
    -d training_data_config.yaml \
    --dataset-dir ./preprocessed_data \
    --result-dir pretraining_demo \
    --experiment-name evo2 \
    --model-size {model_size}    \
    --devices 4 \
    --num-nodes 1 \
    --seq-length 8192 \
    --micro-batch-size 2 \
    --lr 0.000015 \
    --min-lr 0.0000149 \
    --warmup-steps {warmup_steps} \
    --grad-acc-batches 4 \
    --max-steps {MAX_STEPS} \
    --ckpt-dir /workspaces/bionemo-framework/checkpoints/nemo2_evo2_{model_size}_8k \
    --clip-grad 250 \
    --wd 0.001 \
    --attention-dropout 0.01 \
    --hidden-dropout 0.01 \
    --val-check-interval {val_check_interval} \
    {model_subset_option} \
    --create-tensorboard-logger \
    --ckpt-async-save"""

# !{train_cmd}
# Out:
# Could not find the bitsandbytes CUDA binary at PosixPath('/usr/local/lib/python3.12/dist-packages/bitsandbytes/libbitsandbytes_cuda129.so')
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Using byte-level tokenization
# [NeMo W 2025-06-25 05:56:24 nemo_logging:405] WandB is currently turned off.
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Experiments will be logged at pretraining_demo/evo2/dev
# [NeMo W 2025-06-25 05:56:24 nemo_logging:405] There were no checkpoints found in checkpoint_dir or no checkpoint folder at checkpoint_dir :pretraining_demo/evo2/checkpoints. Training from scratch.
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Fixing mis-match between ddp-config & mcore-optimizer config
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has data parallel group : [0, 1, 2, 3]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has combined group of data parallel and context parallel : [0, 1, 2, 3]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] All data parallel group ranks with context parallel combined: [[0, 1, 2, 3]]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Ranks 0 has data parallel rank: 0
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has context parallel group: [0]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] All context parallel group ranks: [[0], [1], [2], [3]]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Ranks 0 has context parallel rank: 0
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has model parallel group: [0]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] All model parallel group ranks: [[0], [1], [2], [3]]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has tensor model parallel group: [0]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] All tensor model parallel group ranks: [[0], [1], [2], [3]]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has pipeline model parallel group: [0]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has embedding group: [0]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] All pipeline model parallel group ranks: [[0], [1], [2], [3]]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] All embedding group ranks: [[0], [1], [2], [3]]
# [NeMo I 2025-06-25 05:56:24 nemo_logging:393] Rank 0 has embedding rank: 0
# Could not find the bitsandbytes CUDA binary at PosixPath('/usr/local/lib/python3.12/dist-packages/bitsandbytes/libbitsandbytes_cuda129.so')
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# Could not find the bitsandbytes CUDA binary at PosixPath('/usr/local/lib/python3.12/dist-packages/bitsandbytes/libbitsandbytes_cuda129.so')
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# Could not find the bitsandbytes CUDA binary at PosixPath('/usr/local/lib/python3.12/dist-packages/bitsandbytes/libbitsandbytes_cuda129.so')
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [NeMo I 2025-06-25 05:56:44 utils:554] Building Evo2Dataset splits with sizes=[3200, 1920, 32] and config=GPTDatasetConfig(random_seed=1234, sequence_length=8192, blend=None, blend_per_split=[(['/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_train'], [1.0]), (['/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_val'], [1.0]), (['/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_test'], [1.0])], split=None, split_matrix=None, num_dataset_builder_threads=1, path_to_cache=None, mmap_bin_files=True, mock=False, tokenizer=<nemo.collections.common.tokenizers.bytelevel_tokenizers.ByteLevelTokenizer object at 0x7f1fa1fc0ef0>, mid_level_dataset_surplus=0.005, reset_position_ids=False, reset_attention_mask=False, eod_mask_loss=False, create_attention_mask=False, drop_last_partial_validation_sequence=True, add_extra_token_to_sequence=True, object_storage_cache_path=None)
# [NeMo I 2025-06-25 05:56:44 utils:554] Load the _IndexReader from /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_train.idx
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the sequence lengths
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the sequence pointers
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the document indices
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of sequences: 2
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of documents: 2
# [NeMo I 2025-06-25 05:56:44 utils:554] Load the Evo2Dataset train indices
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the document index from b0bea0af8a3b270425b0e51f6355a42a-Evo2Dataset-train-document_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the sample index from b0bea0af8a3b270425b0e51f6355a42a-Evo2Dataset-train-sample_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the shuffle index from b0bea0af8a3b270425b0e51f6355a42a-Evo2Dataset-train-shuffle_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of samples: 11403
# [NeMo I 2025-06-25 05:56:44 utils:554] Load the _IndexReader from /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_val.idx
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the sequence lengths
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the sequence pointers
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the document indices
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of sequences: 2
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of documents: 2
# [NeMo I 2025-06-25 05:56:44 utils:554] Load the Evo2Dataset valid indices
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the document index from ea69e1b07eee60aa0b4eedb01dfed4d9-Evo2Dataset-valid-document_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the sample index from ea69e1b07eee60aa0b4eedb01dfed4d9-Evo2Dataset-valid-sample_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the shuffle index from ea69e1b07eee60aa0b4eedb01dfed4d9-Evo2Dataset-valid-shuffle_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of samples: 15733
# [NeMo I 2025-06-25 05:56:44 utils:554] Load the _IndexReader from /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/preprocessed_data/chr20_21_22_uint8_distinct_byte-level_test.idx
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the sequence lengths
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the sequence pointers
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Extract the document indices
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of sequences: 2
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of documents: 2
# [NeMo I 2025-06-25 05:56:44 utils:554] Load the Evo2Dataset test indices
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the document index from 68e30557a6cd24d16401b6f4b17bcb0f-Evo2Dataset-test-document_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the sample index from 68e30557a6cd24d16401b6f4b17bcb0f-Evo2Dataset-test-sample_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] 	Load the shuffle index from 68e30557a6cd24d16401b6f4b17bcb0f-Evo2Dataset-test-shuffle_index.npy
# [NeMo I 2025-06-25 05:56:44 utils:554] > total number of samples: 12406
# [NeMo I 2025-06-25 05:56:44 nemo_logging:393] Padded vocab_size: 512, original vocab_size: 512, dummy tokens: 0.
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:44 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# [NeMo W 2025-06-25 05:56:45 random:222] CPU RNG state changed within GPU RNG context
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [NeMo I 2025-06-25 05:56:45 nemo_logging:393] Copying Trainer's 'max_steps' (100) to LR scheduler's 'max_steps'.
# [NeMo I 2025-06-25 05:56:45 num_microbatches_calculator:228] setting number of microbatches to constant 4
# [NeMo I 2025-06-25 05:56:45 nemo_logging:393]  > number of parameters on (tensor, pipeline) model parallel rank (0 ,0): 1108204800
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [NeMo I 2025-06-25 05:56:45 utils:554] Setting up DistributedDataParallel with config DistributedDataParallelConfig(grad_reduce_in_fp32=False, overlap_grad_reduce=False, overlap_param_gather=False, align_param_gather=False, use_distributed_optimizer=True, num_distributed_optimizer_instances=1, check_for_nan_in_grad=True, check_for_large_grads=False, bucket_size=None, pad_buckets_for_high_nccl_busbw=False, average_in_collective=True, fp8_param_gather=False, use_custom_fsdp=False, data_parallel_sharding_strategy='no_shard', gradient_reduce_div_fusion=True, suggested_communication_unit_size=None, preserve_fp32_weights=True, keep_fp8_transpose_cache_when_using_custom_fsdp=False)
# [NeMo I 2025-06-25 05:56:45 utils:575] Number of buckets for gradient all-reduce / reduce-scatter: 1
#     Params for bucket 1 (1108204800 elements, 1108204800 padded size):
#     	module.decoder.layers.23.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.20.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.17.self_attention.linear_qkv.weight
#     	module.decoder.layers.13.mixer.mixer.filter.gamma
#     	module.decoder.layers.10.self_attention.linear_qkv.weight
#     	module.decoder.layers.6.mixer.mixer.filter.gamma
#     	module.decoder.layers.23.mlp.linear_fc1.weight
#     	module.decoder.layers.20.mixer.mixer.conv_bias
#     	module.decoder.layers.16.mixer.dense_projection.weight
#     	module.decoder.layers.12.mixer.mixer.filter.h
#     	module.decoder.layers.9.mixer.dense_projection.weight
#     	module.decoder.layers.22.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.16.mlp.linear_fc2.weight
#     	module.decoder.layers.14.mlp.linear_fc1.weight
#     	module.decoder.layers.12.mixer.dense.weight
#     	module.decoder.layers.9.mlp.linear_fc2.weight
#     	module.decoder.layers.7.mlp.linear_fc1.weight
#     	module.decoder.layers.5.mixer.dense.weight
#     	module.decoder.layers.2.mixer.mixer.filter.R
#     	module.decoder.layers.1.mixer.dense_projection.weight
#     	module.decoder.layers.0.mixer.dense.bias
#     	module.decoder.layers.23.mixer.dense.bias
#     	module.decoder.layers.21.mixer.dense_projection.weight
#     	module.decoder.layers.19.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.18.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.16.mixer.mixer.conv_bias
#     	module.decoder.layers.13.mixer.mixer.filter.p
#     	module.decoder.layers.11.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.9.mixer.mixer.conv_bias
#     	module.decoder.layers.6.mixer.mixer.filter.p
#     	module.decoder.layers.4.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.24.self_attention.linear_qkv.weight
#     	module.decoder.layers.20.mixer.mixer.filter.gamma
#     	module.decoder.layers.14.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.12.mixer.dense_projection.weight
#     	module.decoder.layers.7.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.5.mixer.dense_projection.weight
#     	module.decoder.layers.1.mlp.linear_fc2.weight
#     	module.embedding.word_embeddings.weight
#     	module.decoder.layers.23.mixer.dense_projection.weight
#     	module.decoder.layers.18.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.17.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.13.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.10.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.6.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.3.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.2.mixer.dense.weight
#     	module.decoder.layers.1.mlp.linear_fc1.weight
#     	module.decoder.layers.1.mixer.dense.bias
#     	module.decoder.layers.23.mlp.linear_fc2.weight
#     	module.decoder.layers.21.mlp.linear_fc1.weight
#     	module.decoder.layers.19.mixer.dense.weight
#     	module.decoder.layers.13.mlp.linear_fc1.weight
#     	module.decoder.layers.12.mixer.mixer.conv_bias
#     	module.decoder.layers.6.mlp.linear_fc1.weight
#     	module.decoder.layers.5.mixer.mixer.filter.h
#     	module.decoder.layers.1.mixer.mixer.conv_bias
#     	module.decoder.layers.23.mixer.mixer.conv_bias
#     	module.decoder.layers.20.mixer.mixer.filter.p
#     	module.decoder.layers.17.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.14.mlp.linear_fc2.weight
#     	module.decoder.layers.12.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.10.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.7.mlp.linear_fc2.weight
#     	module.decoder.layers.5.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.0.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.21.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.19.mixer.dense_projection.weight
#     	module.decoder.layers.18.mixer.dense_projection.weight
#     	module.decoder.layers.15.mlp.linear_fc1.weight
#     	module.decoder.layers.13.mixer.dense.bias
#     	module.decoder.layers.11.mixer.dense_projection.weight
#     	module.decoder.layers.8.mlp.linear_fc1.weight
#     	module.decoder.layers.6.mixer.dense.bias
#     	module.decoder.layers.4.mixer.dense_projection.weight
#     	module.decoder.layers.3.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.24.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.24.self_attention.linear_proj.bias
#     	module.decoder.layers.20.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.14.mixer.dense.weight
#     	module.decoder.layers.7.mixer.dense.weight
#     	module.decoder.layers.2.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.1.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.20.mlp.linear_fc1.weight
#     	module.decoder.layers.18.mlp.linear_fc2.weight
#     	module.decoder.layers.13.mixer.dense_projection.weight
#     	module.decoder.layers.6.mixer.dense_projection.weight
#     	module.decoder.layers.3.mlp.linear_fc2.weight
#     	module.decoder.layers.2.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.1.mixer.mixer.filter.h
#     	module.decoder.layers.24.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.21.mlp.linear_fc2.weight
#     	module.decoder.layers.19.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.16.mixer.mixer.filter.R
#     	module.decoder.layers.13.mlp.linear_fc2.weight
#     	module.decoder.layers.11.mlp.linear_fc1.weight
#     	module.decoder.layers.9.mixer.mixer.filter.R
#     	module.decoder.layers.6.mlp.linear_fc2.weight
#     	module.decoder.layers.4.mlp.linear_fc1.weight
#     	module.decoder.layers.1.mixer.dense.weight
#     	module.decoder.layers.22.mlp.linear_fc1.weight
#     	module.decoder.layers.20.mixer.dense.bias
#     	module.decoder.layers.15.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.13.mixer.mixer.conv_bias
#     	module.decoder.layers.8.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.7.mixer.dense.bias
#     	module.decoder.layers.0.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.21.mixer.dense.weight
#     	module.decoder.layers.18.mlp.linear_fc1.weight
#     	module.decoder.layers.15.mlp.linear_fc2.weight
#     	module.decoder.layers.11.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.8.mlp.linear_fc2.weight
#     	module.decoder.layers.4.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.20.mixer.dense_projection.weight
#     	module.decoder.layers.16.mixer.dense.weight
#     	module.decoder.layers.9.mixer.dense.weight
#     	module.decoder.layers.2.mixer.mixer.filter.gamma
#     	module.decoder.layers.23.mixer.mixer.filter.R
#     	module.decoder.layers.20.mlp.linear_fc2.weight
#     	module.decoder.layers.17.mlp.linear_fc1.weight
#     	module.decoder.layers.10.mlp.linear_fc1.weight
#     	module.decoder.layers.0.mlp.linear_fc1.weight
#     	module.decoder.layers.0.mixer.dense_projection.weight
#     	module.decoder.layers.22.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.21.mixer.dense.bias
#     	module.decoder.layers.14.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.11.mlp.linear_fc2.weight
#     	module.decoder.layers.7.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.4.mlp.linear_fc2.weight
#     	module.decoder.layers.22.mlp.linear_fc2.weight
#     	module.decoder.layers.12.mlp.linear_fc1.weight
#     	module.decoder.layers.5.mlp.linear_fc1.weight
#     	module.decoder.layers.2.mixer.mixer.filter.p
#     	module.decoder.layers.0.mixer.dense.weight
#     	module.decoder.layers.23.mixer.dense.weight
#     	module.decoder.layers.16.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.15.mixer.mixer.conv_bias
#     	module.decoder.layers.11.mixer.dense.weight
#     	module.decoder.layers.9.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.8.mixer.mixer.conv_bias
#     	module.decoder.layers.4.mixer.dense.weight
#     	module.decoder.layers.24.mlp.linear_fc1.weight
#     	module.decoder.layers.16.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.9.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.2.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.0.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.17.mlp.linear_fc2.weight
#     	module.decoder.layers.21.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.18.mixer.dense.weight
#     	module.decoder.layers.13.mixer.mixer.filter.R
#     	module.decoder.layers.11.mixer.dense.bias
#     	module.decoder.layers.10.mlp.linear_fc2.weight
#     	module.decoder.layers.6.mixer.mixer.filter.R
#     	module.decoder.layers.4.mixer.dense.bias
#     	module.decoder.layers.2.mlp.linear_fc1.weight
#     	module.decoder.layers.0.mlp.linear_fc2.weight
#     	module.decoder.layers.19.mlp.linear_fc1.weight
#     	module.decoder.layers.14.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.12.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.7.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.5.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.2.mixer.mixer.conv_bias
#     	module.decoder.layers.23.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.22.mixer.mixer.conv_bias
#     	module.decoder.layers.19.mixer.mixer.filter.h
#     	module.decoder.layers.15.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.12.mlp.linear_fc2.weight
#     	module.decoder.layers.12.mixer.dense.bias
#     	module.decoder.layers.8.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.5.mlp.linear_fc2.weight
#     	module.decoder.layers.2.mixer.dense.bias
#     	module.decoder.layers.0.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.1.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.23.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.16.mixer.mixer.filter.gamma
#     	module.decoder.layers.13.mixer.dense.weight
#     	module.decoder.layers.10.self_attention.linear_proj.bias
#     	module.decoder.layers.9.mixer.mixer.filter.gamma
#     	module.decoder.layers.6.mixer.dense.weight
#     	module.decoder.layers.3.self_attention.linear_qkv.weight
#     	module.decoder.final_norm.weight
#     	module.decoder.layers.24.mlp.linear_fc2.weight
#     	module.decoder.layers.20.mixer.mixer.filter.R
#     	module.decoder.layers.17.self_attention.linear_proj.weight
#     	module.decoder.layers.15.mixer.mixer.filter.h
#     	module.decoder.layers.10.self_attention.linear_proj.weight
#     	module.decoder.layers.8.mixer.mixer.filter.h
#     	module.decoder.layers.5.mixer.dense.bias
#     	module.decoder.layers.2.mixer.dense_projection.weight
#     	module.decoder.layers.21.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.19.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.18.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.15.mixer.dense.bias
#     	module.decoder.layers.15.mixer.dense.weight
#     	module.decoder.layers.11.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.8.mixer.dense.bias
#     	module.decoder.layers.8.mixer.dense.weight
#     	module.decoder.layers.4.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.2.mlp.linear_fc2.weight
#     	module.decoder.layers.22.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.19.mlp.linear_fc2.weight
#     	module.decoder.layers.16.mixer.mixer.filter.p
#     	module.decoder.layers.14.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.9.mixer.mixer.filter.p
#     	module.decoder.layers.7.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.5.mixer.mixer.conv_bias
#     	module.decoder.layers.1.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.23.mixer.mixer.filter.gamma
#     	module.decoder.layers.20.mixer.dense.weight
#     	module.decoder.layers.15.mixer.dense_projection.weight
#     	module.decoder.layers.13.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.8.mixer.dense_projection.weight
#     	module.decoder.layers.6.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.24.self_attention.linear_proj.weight
#     	module.decoder.layers.22.mixer.mixer.filter.h
#     	module.decoder.layers.19.mixer.dense.bias
#     	module.decoder.layers.18.mixer.dense.bias
#     	module.decoder.layers.16.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.13.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.9.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.6.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.3.mlp.linear_fc1.weight
#     	module.decoder.layers.3.self_attention.linear_proj.bias
#     	module.decoder.layers.22.mixer.dense.bias
#     	module.decoder.layers.22.mixer.dense.weight
#     	module.decoder.layers.16.mlp.linear_fc1.weight
#     	module.decoder.layers.14.mixer.dense.bias
#     	module.decoder.layers.9.mlp.linear_fc1.weight
#     	module.decoder.layers.6.mixer.mixer.conv_bias
#     	module.decoder.layers.18.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.17.self_attention.linear_proj.bias
#     	module.decoder.layers.23.mixer.mixer.filter.p
#     	module.decoder.layers.21.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.19.mixer.mixer.conv_bias
#     	module.decoder.layers.15.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.11.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.8.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.4.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.3.self_attention.linear_proj.weight
#     	module.decoder.layers.22.mixer.dense_projection.weight
#     	module.decoder.layers.20.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.16.mixer.dense.bias
#     	module.decoder.layers.14.mixer.dense_projection.weight
#     	module.decoder.layers.12.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.9.mixer.dense.bias
#     	module.decoder.layers.7.mixer.dense_projection.weight
#     	module.decoder.layers.5.mixer.hyena_proj_conv.short_conv_weight
# [NeMo I 2025-06-25 05:56:45 utils:554] Setting up optimizer with config OptimizerConfig(optimizer='adam', lr=1.5e-05, min_lr=None, decoupled_lr=None, decoupled_min_lr=None, weight_decay=0.001, fp16=False, bf16=True, params_dtype=torch.bfloat16, use_precision_aware_optimizer=False, store_param_remainders=True, main_grads_dtype=torch.float32, main_params_dtype=torch.float32, exp_avg_dtype=torch.float32, exp_avg_sq_dtype=torch.float32, loss_scale=None, initial_loss_scale=4294967296, min_loss_scale=1.0, loss_scale_window=1000, hysteresis=2, adam_beta1=0.9, adam_beta2=0.95, adam_eps=1e-08, sgd_momentum=0.9, use_distributed_optimizer=True, overlap_param_gather_with_optimizer_step=False, optimizer_cpu_offload=False, optimizer_offload_fraction=0.0, use_torch_optimizer_for_cpu_offload=False, overlap_cpu_optimizer_d2h_h2d=False, pin_cpu_grads=True, pin_cpu_params=True, clip_grad=250.0, log_num_zeros_in_grad=False, barrier_with_L1_time=False, timers=None, config_logger_dir='')
# [NeMo I 2025-06-25 05:56:45 nemo_logging:393] Doing selective restore from RestoreConfig(path='/workspaces/bionemo-framework/checkpoints/nemo2_evo2_1b_8k', adapter_path=None, load_model_state=True, load_optim_state=False, load_artifacts=True)
# [NeMo I 2025-06-25 05:56:45 nemo_logging:393] Using <megatron.core.dist_checkpointing.strategies.fully_parallel.FullyParallelLoadStrategyWrapper object at 0x7f1f84d3da90> dist-ckpt load strategy.
# [NeMo I 2025-06-25 05:56:54 nemo_logging:393] Global Checkpoint Load : Rank : 0 : Start time : 1750831005.359s : Time spent in load_checkpoint: 9.014s
# [NeMo I 2025-06-25 05:56:54 nemo_logging:393] Restoring model weights from RestoreConfig(path='/workspaces/bionemo-framework/checkpoints/nemo2_evo2_1b_8k', adapter_path=None, load_model_state=True, load_optim_state=False, load_artifacts=True)
# [NeMo I 2025-06-25 05:56:54 nemo_logging:393] Finished restoring from RestoreConfig(path='/workspaces/bionemo-framework/checkpoints/nemo2_evo2_1b_8k', adapter_path=None, load_model_state=True, load_optim_state=False, load_artifacts=True), cleaning up.
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name                                ┃ Type              ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ module                              │ DDP               │  1.1 B │ train │
# │ 1 │ module.module                       │ Float16Module     │  1.1 B │ train │
# │ 2 │ module.module.module                │ HyenaModel        │  1.1 B │ train │
# │ 3 │ module.module.module.embedding      │ LanguageModelEmb… │  983 K │ train │
# │ 4 │ module.module.module.rotary_pos_emb │ RotaryEmbedding   │      0 │ train │
# │ 5 │ module.module.module.decoder        │ HyenaStack        │  1.1 B │ train │
# │ 6 │ module.module.module.output_layer   │ ColumnParallelLi… │      0 │ train │
# └───┴─────────────────────────────────────┴───────────────────┴────────┴───────┘
# Trainable params: 1.1 B
# Non-trainable params: 0
# Total params: 1.1 B
# Total estimated model params size (MB): 4.4 K
# Modules in train mode: 356
# Modules in eval mode: 0
# [NeMo W 2025-06-25 05:57:08 rerun_state_machine:1264] Implicit initialization of Rerun State Machine!
# [NeMo W 2025-06-25 05:57:08 rerun_state_machine:239] RerunStateMachine initialized in mode RerunMode.DISABLED
# Training epoch 0, iteration 0/99 | lr: 0 | global_batch_size: 32 | global_step: 0 | reduced_train_loss: 0.9721 | train_step_timing in s: 17.26
# Training epoch 0, iteration 1/99 | lr: 1.5e-07 | global_batch_size: 32 | global_step: 1 | reduced_train_loss: 1.13 | train_step_timing in s: 2.461 | consumed_samples: 64
# Training epoch 0, iteration 2/99 | lr: 3e-07 | global_batch_size: 32 | global_step: 2 | reduced_train_loss: 1.018 | train_step_timing in s: 2.46 | consumed_samples: 96
# Training epoch 0, iteration 3/99 | lr: 4.5e-07 | global_batch_size: 32 | global_step: 3 | reduced_train_loss: 0.9231 | train_step_timing in s: 2.463 | consumed_samples: 128
# Training epoch 0, iteration 4/99 | lr: 6e-07 | global_batch_size: 32 | global_step: 4 | reduced_train_loss: 0.9804 | train_step_timing in s: 2.464 | consumed_samples: 160
# Training epoch 0, iteration 5/99 | lr: 7.5e-07 | global_batch_size: 32 | global_step: 5 | reduced_train_loss: 1.102 | train_step_timing in s: 2.466 | consumed_samples: 192
# Training epoch 0, iteration 6/99 | lr: 9e-07 | global_batch_size: 32 | global_step: 6 | reduced_train_loss: 1.083 | train_step_timing in s: 2.466 | consumed_samples: 224
# Training epoch 0, iteration 7/99 | lr: 1.05e-06 | global_batch_size: 32 | global_step: 7 | reduced_train_loss: 0.7939 | train_step_timing in s: 2.469 | consumed_samples: 256
# Training epoch 0, iteration 8/99 | lr: 1.2e-06 | global_batch_size: 32 | global_step: 8 | reduced_train_loss: 0.9516 | train_step_timing in s: 2.469 | consumed_samples: 288
# Training epoch 0, iteration 9/99 | lr: 1.35e-06 | global_batch_size: 32 | global_step: 9 | reduced_train_loss: 0.8948 | train_step_timing in s: 2.467 | consumed_samples: 320
# Training epoch 0, iteration 10/99 | lr: 1.5e-06 | global_batch_size: 32 | global_step: 10 | reduced_train_loss: 0.9447 | train_step_timing in s: 2.467 | consumed_samples: 352
# Training epoch 0, iteration 11/99 | lr: 1.65e-06 | global_batch_size: 32 | global_step: 11 | reduced_train_loss: 1.037 | train_step_timing in s: 2.465 | consumed_samples: 384
# Training epoch 0, iteration 12/99 | lr: 1.8e-06 | global_batch_size: 32 | global_step: 12 | reduced_train_loss: 1.048 | train_step_timing in s: 2.466 | consumed_samples: 416
# Training epoch 0, iteration 13/99 | lr: 1.95e-06 | global_batch_size: 32 | global_step: 13 | reduced_train_loss: 0.8128 | train_step_timing in s: 2.467 | consumed_samples: 448
# Training epoch 0, iteration 14/99 | lr: 2.1e-06 | global_batch_size: 32 | global_step: 14 | reduced_train_loss: 1.239 | train_step_timing in s: 2.465 | consumed_samples: 480
# Training epoch 0, iteration 15/99 | lr: 2.25e-06 | global_batch_size: 32 | global_step: 15 | reduced_train_loss: 1.139 | train_step_timing in s: 2.467 | consumed_samples: 512
# Training epoch 0, iteration 16/99 | lr: 2.4e-06 | global_batch_size: 32 | global_step: 16 | reduced_train_loss: 1.053 | train_step_timing in s: 2.468 | consumed_samples: 544
# Training epoch 0, iteration 17/99 | lr: 2.55e-06 | global_batch_size: 32 | global_step: 17 | reduced_train_loss: 1.109 | train_step_timing in s: 2.467 | consumed_samples: 576
# Training epoch 0, iteration 18/99 | lr: 2.7e-06 | global_batch_size: 32 | global_step: 18 | reduced_train_loss: 1.04 | train_step_timing in s: 2.466 | consumed_samples: 608
# Training epoch 0, iteration 19/99 | lr: 2.85e-06 | global_batch_size: 32 | global_step: 19 | reduced_train_loss: 1.176 | train_step_timing in s: 2.466 | consumed_samples: 640
# Training epoch 0, iteration 20/99 | lr: 3e-06 | global_batch_size: 32 | global_step: 20 | reduced_train_loss: 1.091 | train_step_timing in s: 2.467 | consumed_samples: 672
# Training epoch 0, iteration 21/99 | lr: 3.15e-06 | global_batch_size: 32 | global_step: 21 | reduced_train_loss: 1.063 | train_step_timing in s: 2.468 | consumed_samples: 704
# Training epoch 0, iteration 22/99 | lr: 3.3e-06 | global_batch_size: 32 | global_step: 22 | reduced_train_loss: 1.055 | train_step_timing in s: 2.47 | consumed_samples: 736
# Training epoch 0, iteration 23/99 | lr: 3.45e-06 | global_batch_size: 32 | global_step: 23 | reduced_train_loss: 1.168 | train_step_timing in s: 2.469 | consumed_samples: 768
# Training epoch 0, iteration 24/99 | lr: 3.6e-06 | global_batch_size: 32 | global_step: 24 | reduced_train_loss: 1.02 | train_step_timing in s: 2.468 | consumed_samples: 800
# Training epoch 0, iteration 25/99 | lr: 3.75e-06 | global_batch_size: 32 | global_step: 25 | reduced_train_loss: 0.9001 | train_step_timing in s: 2.47 | consumed_samples: 832
# Training epoch 0, iteration 26/99 | lr: 3.9e-06 | global_batch_size: 32 | global_step: 26 | reduced_train_loss: 1.128 | train_step_timing in s: 2.47 | consumed_samples: 864
# Training epoch 0, iteration 27/99 | lr: 4.05e-06 | global_batch_size: 32 | global_step: 27 | reduced_train_loss: 1.042 | train_step_timing in s: 2.47 | consumed_samples: 896
# Training epoch 0, iteration 28/99 | lr: 4.2e-06 | global_batch_size: 32 | global_step: 28 | reduced_train_loss: 0.9442 | train_step_timing in s: 2.47 | consumed_samples: 928
# Training epoch 0, iteration 29/99 | lr: 4.35e-06 | global_batch_size: 32 | global_step: 29 | reduced_train_loss: 1.126 | train_step_timing in s: 2.47 | consumed_samples: 960
# Training epoch 0, iteration 30/99 | lr: 4.5e-06 | global_batch_size: 32 | global_step: 30 | reduced_train_loss: 0.9144 | train_step_timing in s: 2.471 | consumed_samples: 992
# Training epoch 0, iteration 31/99 | lr: 4.65e-06 | global_batch_size: 32 | global_step: 31 | reduced_train_loss: 0.9327 | train_step_timing in s: 2.47 | consumed_samples: 1024
# Training epoch 0, iteration 32/99 | lr: 4.8e-06 | global_batch_size: 32 | global_step: 32 | reduced_train_loss: 0.8176 | train_step_timing in s: 2.47 | consumed_samples: 1056
# Training epoch 0, iteration 33/99 | lr: 4.95e-06 | global_batch_size: 32 | global_step: 33 | reduced_train_loss: 1.17 | train_step_timing in s: 2.47 | consumed_samples: 1088
# Training epoch 0, iteration 34/99 | lr: 5.1e-06 | global_batch_size: 32 | global_step: 34 | reduced_train_loss: 1.093 | train_step_timing in s: 2.47 | consumed_samples: 1120
# Training epoch 0, iteration 35/99 | lr: 5.25e-06 | global_batch_size: 32 | global_step: 35 | reduced_train_loss: 0.9762 | train_step_timing in s: 2.472 | consumed_samples: 1152
# Training epoch 0, iteration 36/99 | lr: 5.4e-06 | global_batch_size: 32 | global_step: 36 | reduced_train_loss: 1.052 | train_step_timing in s: 2.47 | consumed_samples: 1184
# Training epoch 0, iteration 37/99 | lr: 5.55e-06 | global_batch_size: 32 | global_step: 37 | reduced_train_loss: 1.053 | train_step_timing in s: 2.47 | consumed_samples: 1216
# Training epoch 0, iteration 38/99 | lr: 5.7e-06 | global_batch_size: 32 | global_step: 38 | reduced_train_loss: 1.135 | train_step_timing in s: 2.469 | consumed_samples: 1248
# Training epoch 0, iteration 39/99 | lr: 5.85e-06 | global_batch_size: 32 | global_step: 39 | reduced_train_loss: 1.103 | train_step_timing in s: 2.47 | consumed_samples: 1280
# Training epoch 0, iteration 40/99 | lr: 6e-06 | global_batch_size: 32 | global_step: 40 | reduced_train_loss: 0.9852 | train_step_timing in s: 2.469 | consumed_samples: 1312
# Training epoch 0, iteration 41/99 | lr: 6.15e-06 | global_batch_size: 32 | global_step: 41 | reduced_train_loss: 0.957 | train_step_timing in s: 2.47 | consumed_samples: 1344
# Training epoch 0, iteration 42/99 | lr: 6.3e-06 | global_batch_size: 32 | global_step: 42 | reduced_train_loss: 0.8952 | train_step_timing in s: 2.471 | consumed_samples: 1376
# Training epoch 0, iteration 43/99 | lr: 6.45e-06 | global_batch_size: 32 | global_step: 43 | reduced_train_loss: 1.266 | train_step_timing in s: 2.469 | consumed_samples: 1408
# Training epoch 0, iteration 44/99 | lr: 6.6e-06 | global_batch_size: 32 | global_step: 44 | reduced_train_loss: 1.079 | train_step_timing in s: 2.466 | consumed_samples: 1440
# Training epoch 0, iteration 45/99 | lr: 6.75e-06 | global_batch_size: 32 | global_step: 45 | reduced_train_loss: 1.066 | train_step_timing in s: 2.469 | consumed_samples: 1472
# Training epoch 0, iteration 46/99 | lr: 6.9e-06 | global_batch_size: 32 | global_step: 46 | reduced_train_loss: 1.127 | train_step_timing in s: 2.47 | consumed_samples: 1504
# Training epoch 0, iteration 47/99 | lr: 7.05e-06 | global_batch_size: 32 | global_step: 47 | reduced_train_loss: 1.187 | train_step_timing in s: 2.469 | consumed_samples: 1536
# Training epoch 0, iteration 48/99 | lr: 7.2e-06 | global_batch_size: 32 | global_step: 48 | reduced_train_loss: 0.9197 | train_step_timing in s: 2.47 | consumed_samples: 1568
# Training epoch 0, iteration 49/99 | lr: 7.35e-06 | global_batch_size: 32 | global_step: 49 | reduced_train_loss: 1.109 | train_step_timing in s: 2.47 | consumed_samples: 1600
# Epoch 0, global step 49: 'val_loss' was not in top 5
# [NeMo I 2025-06-25 05:59:14 nemo_logging:393] Using FullyParallelSaveStrategyWrapper(torch_dist, 1) dist-ckpt save strategy.
# [NeMo I 2025-06-25 05:59:15 nemo_logging:393] Global Checkpoint Save : Rank: 0 : Iteration: 49 : Start time: 1750831154.907s : Save duration: 0.332s
# [NeMo I 2025-06-25 05:59:17 nemo_logging:393] Scheduled async checkpoint save for /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=49-consumed_samples=1600.0-last.ckpt
# [NeMo I 2025-06-25 05:59:17 nemo_logging:393] Async finalization time took 0.001 s
# Validation: iteration 1/20
# Validation: iteration 2/20
# Validation: iteration 3/20
# Validation: iteration 4/20
# Validation: iteration 5/20
# Validation: iteration 6/20
# Validation: iteration 7/20
# Validation: iteration 8/20
# Validation: iteration 9/20
# Validation: iteration 10/20
# Validation: iteration 11/20
# Validation: iteration 12/20
# Validation: iteration 13/20
# Validation: iteration 14/20
# Validation: iteration 15/20
# Validation: iteration 16/20
# Validation: iteration 17/20
# Validation: iteration 18/20
# Validation: iteration 19/20
# Validation: iteration 20/20
# [NeMo W 2025-06-25 05:59:33 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('global_batch_size', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#
# [NeMo W 2025-06-25 05:59:33 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#
# Training epoch 0, iteration 50/99 | lr: 7.5e-06 | global_batch_size: 32 | global_step: 50 | reduced_train_loss: 1.059 | train_step_timing in s: 2.471 | consumed_samples: 1632 | val_loss: 1.225
# [NeMo I 2025-06-25 05:59:36 nemo_logging:393] Async finalization time took 0.000 s
# Training epoch 0, iteration 51/99 | lr: 7.65e-06 | global_batch_size: 32 | global_step: 51 | reduced_train_loss: 0.9072 | train_step_timing in s: 2.468 | consumed_samples: 1664 | val_loss: 1.225
# [NeMo I 2025-06-25 05:59:39 nemo_logging:393] Async finalization time took 0.000 s
# Training epoch 0, iteration 52/99 | lr: 7.8e-06 | global_batch_size: 32 | global_step: 52 | reduced_train_loss: 1.0 | train_step_timing in s: 2.47 | consumed_samples: 1696 | val_loss: 1.225
# [NeMo I 2025-06-25 05:59:43 nemo_logging:393] Async finalization time took 0.000 s
# Training epoch 0, iteration 53/99 | lr: 7.95e-06 | global_batch_size: 32 | global_step: 53 | reduced_train_loss: 1.1 | train_step_timing in s: 2.469 | consumed_samples: 1728 | val_loss: 1.225
# [NeMo I 2025-06-25 05:59:46 nemo_logging:393] Async finalization time took 0.001 s
# Training epoch 0, iteration 54/99 | lr: 8.1e-06 | global_batch_size: 32 | global_step: 54 | reduced_train_loss: 1.036 | train_step_timing in s: 2.469 | consumed_samples: 1760 | val_loss: 1.225
# [NeMo I 2025-06-25 05:59:49 nemo_logging:393] Successfully saved checkpoint from iteration      49 to /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=49-consumed_samples=1600.0-last.ckpt
# [NeMo I 2025-06-25 05:59:49 nemo_logging:393] Async checkpoint save for step 50 (/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=49-consumed_samples=1600.0-last.ckpt) finalized successfully.
# [NeMo I 2025-06-25 05:59:49 nemo_logging:393] Async finalization time took 0.075 s
# Training epoch 0, iteration 55/99 | lr: 8.25e-06 | global_batch_size: 32 | global_step: 55 | reduced_train_loss: 0.9058 | train_step_timing in s: 2.47 | consumed_samples: 1792 | val_loss: 1.225
# Training epoch 0, iteration 56/99 | lr: 8.4e-06 | global_batch_size: 32 | global_step: 56 | reduced_train_loss: 0.7129 | train_step_timing in s: 2.466 | consumed_samples: 1824 | val_loss: 1.225
# Training epoch 0, iteration 57/99 | lr: 8.55e-06 | global_batch_size: 32 | global_step: 57 | reduced_train_loss: 1.059 | train_step_timing in s: 2.468 | consumed_samples: 1856 | val_loss: 1.225
# Training epoch 0, iteration 58/99 | lr: 8.7e-06 | global_batch_size: 32 | global_step: 58 | reduced_train_loss: 0.9337 | train_step_timing in s: 2.472 | consumed_samples: 1888 | val_loss: 1.225
# Training epoch 0, iteration 59/99 | lr: 8.85e-06 | global_batch_size: 32 | global_step: 59 | reduced_train_loss: 1.145 | train_step_timing in s: 2.47 | consumed_samples: 1920 | val_loss: 1.225
# Training epoch 0, iteration 60/99 | lr: 9e-06 | global_batch_size: 32 | global_step: 60 | reduced_train_loss: 1.193 | train_step_timing in s: 2.47 | consumed_samples: 1952 | val_loss: 1.225
# Training epoch 0, iteration 61/99 | lr: 9.15e-06 | global_batch_size: 32 | global_step: 61 | reduced_train_loss: 1.02 | train_step_timing in s: 2.471 | consumed_samples: 1984 | val_loss: 1.225
# Training epoch 0, iteration 62/99 | lr: 9.3e-06 | global_batch_size: 32 | global_step: 62 | reduced_train_loss: 1.019 | train_step_timing in s: 2.469 | consumed_samples: 2016 | val_loss: 1.225
# Training epoch 0, iteration 63/99 | lr: 9.45e-06 | global_batch_size: 32 | global_step: 63 | reduced_train_loss: 1.088 | train_step_timing in s: 2.471 | consumed_samples: 2048 | val_loss: 1.225
# Training epoch 0, iteration 64/99 | lr: 9.6e-06 | global_batch_size: 32 | global_step: 64 | reduced_train_loss: 0.9012 | train_step_timing in s: 2.471 | consumed_samples: 2080 | val_loss: 1.225
# Training epoch 0, iteration 65/99 | lr: 9.75e-06 | global_batch_size: 32 | global_step: 65 | reduced_train_loss: 1.039 | train_step_timing in s: 2.466 | consumed_samples: 2112 | val_loss: 1.225
# Training epoch 0, iteration 66/99 | lr: 9.9e-06 | global_batch_size: 32 | global_step: 66 | reduced_train_loss: 1.029 | train_step_timing in s: 2.469 | consumed_samples: 2144 | val_loss: 1.225
# Training epoch 0, iteration 67/99 | lr: 1.005e-05 | global_batch_size: 32 | global_step: 67 | reduced_train_loss: 0.9649 | train_step_timing in s: 2.471 | consumed_samples: 2176 | val_loss: 1.225
# Training epoch 0, iteration 68/99 | lr: 1.02e-05 | global_batch_size: 32 | global_step: 68 | reduced_train_loss: 1.029 | train_step_timing in s: 2.47 | consumed_samples: 2208 | val_loss: 1.225
# Training epoch 0, iteration 69/99 | lr: 1.035e-05 | global_batch_size: 32 | global_step: 69 | reduced_train_loss: 0.7748 | train_step_timing in s: 2.47 | consumed_samples: 2240 | val_loss: 1.225
# Training epoch 0, iteration 70/99 | lr: 1.05e-05 | global_batch_size: 32 | global_step: 70 | reduced_train_loss: 0.9556 | train_step_timing in s: 2.469 | consumed_samples: 2272 | val_loss: 1.225
# Training epoch 0, iteration 71/99 | lr: 1.065e-05 | global_batch_size: 32 | global_step: 71 | reduced_train_loss: 0.9411 | train_step_timing in s: 2.469 | consumed_samples: 2304 | val_loss: 1.225
# Training epoch 0, iteration 72/99 | lr: 1.08e-05 | global_batch_size: 32 | global_step: 72 | reduced_train_loss: 0.97 | train_step_timing in s: 2.471 | consumed_samples: 2336 | val_loss: 1.225
# Training epoch 0, iteration 73/99 | lr: 1.095e-05 | global_batch_size: 32 | global_step: 73 | reduced_train_loss: 0.9131 | train_step_timing in s: 2.47 | consumed_samples: 2368 | val_loss: 1.225
# Training epoch 0, iteration 74/99 | lr: 1.11e-05 | global_batch_size: 32 | global_step: 74 | reduced_train_loss: 0.9656 | train_step_timing in s: 2.47 | consumed_samples: 2400 | val_loss: 1.225
# Training epoch 0, iteration 75/99 | lr: 1.125e-05 | global_batch_size: 32 | global_step: 75 | reduced_train_loss: 0.9135 | train_step_timing in s: 2.468 | consumed_samples: 2432 | val_loss: 1.225
# Training epoch 0, iteration 76/99 | lr: 1.14e-05 | global_batch_size: 32 | global_step: 76 | reduced_train_loss: 1.109 | train_step_timing in s: 2.469 | consumed_samples: 2464 | val_loss: 1.225
# Training epoch 0, iteration 77/99 | lr: 1.155e-05 | global_batch_size: 32 | global_step: 77 | reduced_train_loss: 0.9808 | train_step_timing in s: 2.469 | consumed_samples: 2496 | val_loss: 1.225
# Training epoch 0, iteration 78/99 | lr: 1.17e-05 | global_batch_size: 32 | global_step: 78 | reduced_train_loss: 1.064 | train_step_timing in s: 2.471 | consumed_samples: 2528 | val_loss: 1.225
# Training epoch 0, iteration 79/99 | lr: 1.185e-05 | global_batch_size: 32 | global_step: 79 | reduced_train_loss: 1.155 | train_step_timing in s: 2.468 | consumed_samples: 2560 | val_loss: 1.225
# Training epoch 0, iteration 80/99 | lr: 1.2e-05 | global_batch_size: 32 | global_step: 80 | reduced_train_loss: 0.9447 | train_step_timing in s: 2.471 | consumed_samples: 2592 | val_loss: 1.225
# Training epoch 0, iteration 81/99 | lr: 1.215e-05 | global_batch_size: 32 | global_step: 81 | reduced_train_loss: 0.7746 | train_step_timing in s: 2.47 | consumed_samples: 2624 | val_loss: 1.225
# Training epoch 0, iteration 82/99 | lr: 1.23e-05 | global_batch_size: 32 | global_step: 82 | reduced_train_loss: 0.9404 | train_step_timing in s: 2.471 | consumed_samples: 2656 | val_loss: 1.225
# Training epoch 0, iteration 83/99 | lr: 1.245e-05 | global_batch_size: 32 | global_step: 83 | reduced_train_loss: 1.257 | train_step_timing in s: 2.469 | consumed_samples: 2688 | val_loss: 1.225
# Training epoch 0, iteration 84/99 | lr: 1.26e-05 | global_batch_size: 32 | global_step: 84 | reduced_train_loss: 1.042 | train_step_timing in s: 2.471 | consumed_samples: 2720 | val_loss: 1.225
# Training epoch 0, iteration 85/99 | lr: 1.275e-05 | global_batch_size: 32 | global_step: 85 | reduced_train_loss: 0.8185 | train_step_timing in s: 2.472 | consumed_samples: 2752 | val_loss: 1.225
# Training epoch 0, iteration 86/99 | lr: 1.29e-05 | global_batch_size: 32 | global_step: 86 | reduced_train_loss: 0.8451 | train_step_timing in s: 2.466 | consumed_samples: 2784 | val_loss: 1.225
# Training epoch 0, iteration 87/99 | lr: 1.305e-05 | global_batch_size: 32 | global_step: 87 | reduced_train_loss: 0.8114 | train_step_timing in s: 2.471 | consumed_samples: 2816 | val_loss: 1.225
# Training epoch 0, iteration 88/99 | lr: 1.32e-05 | global_batch_size: 32 | global_step: 88 | reduced_train_loss: 1.176 | train_step_timing in s: 2.47 | consumed_samples: 2848 | val_loss: 1.225
# Training epoch 0, iteration 89/99 | lr: 1.335e-05 | global_batch_size: 32 | global_step: 89 | reduced_train_loss: 1.134 | train_step_timing in s: 2.47 | consumed_samples: 2880 | val_loss: 1.225
# Training epoch 0, iteration 90/99 | lr: 1.35e-05 | global_batch_size: 32 | global_step: 90 | reduced_train_loss: 1.029 | train_step_timing in s: 2.471 | consumed_samples: 2912 | val_loss: 1.225
# Training epoch 0, iteration 91/99 | lr: 1.365e-05 | global_batch_size: 32 | global_step: 91 | reduced_train_loss: 1.145 | train_step_timing in s: 2.471 | consumed_samples: 2944 | val_loss: 1.225
# Training epoch 0, iteration 92/99 | lr: 1.38e-05 | global_batch_size: 32 | global_step: 92 | reduced_train_loss: 1.201 | train_step_timing in s: 2.47 | consumed_samples: 2976 | val_loss: 1.225
# Training epoch 0, iteration 93/99 | lr: 1.395e-05 | global_batch_size: 32 | global_step: 93 | reduced_train_loss: 0.883 | train_step_timing in s: 2.469 | consumed_samples: 3008 | val_loss: 1.225
# Training epoch 0, iteration 94/99 | lr: 1.41e-05 | global_batch_size: 32 | global_step: 94 | reduced_train_loss: 1.054 | train_step_timing in s: 2.471 | consumed_samples: 3040 | val_loss: 1.225
# Training epoch 0, iteration 95/99 | lr: 1.425e-05 | global_batch_size: 32 | global_step: 95 | reduced_train_loss: 1.151 | train_step_timing in s: 2.47 | consumed_samples: 3072 | val_loss: 1.225
# Training epoch 0, iteration 96/99 | lr: 1.44e-05 | global_batch_size: 32 | global_step: 96 | reduced_train_loss: 1.019 | train_step_timing in s: 2.467 | consumed_samples: 3104 | val_loss: 1.225
# Training epoch 0, iteration 97/99 | lr: 1.455e-05 | global_batch_size: 32 | global_step: 97 | reduced_train_loss: 1.073 | train_step_timing in s: 2.471 | consumed_samples: 3136 | val_loss: 1.225
# Training epoch 0, iteration 98/99 | lr: 1.47e-05 | global_batch_size: 32 | global_step: 98 | reduced_train_loss: 0.9206 | train_step_timing in s: 2.47 | consumed_samples: 3168 | val_loss: 1.225
# Training epoch 0, iteration 99/99 | lr: 1.485e-05 | global_batch_size: 32 | global_step: 99 | reduced_train_loss: 1.096 | train_step_timing in s: 2.47 | consumed_samples: 3200 | val_loss: 1.225
# Epoch 0, global step 99: 'val_loss' reached 1.22530 (best 1.22530), saving model to '/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0.ckpt' as top 5
# [NeMo I 2025-06-25 06:01:44 nemo_logging:393] Global Checkpoint Save : Rank: 0 : Iteration: 99 : Start time: 1750831302.125s : Save duration: 2.054s
# [NeMo I 2025-06-25 06:01:45 nemo_logging:393] Scheduled async checkpoint save for /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0.ckpt
# [NeMo I 2025-06-25 06:01:45 nemo_logging:393] Global Checkpoint Save : Rank: 0 : Iteration: 99 : Start time: 1750831305.447s : Save duration: 0.326s
# [NeMo I 2025-06-25 06:01:47 nemo_logging:393] Scheduled async checkpoint save for /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0-last.ckpt
# [NeMo I 2025-06-25 06:01:47 nemo_logging:393] Async finalization time took 0.001 s
# Validation: iteration 1/20
# Validation: iteration 2/20
# Validation: iteration 3/20
# Validation: iteration 4/20
# Validation: iteration 5/20
# Validation: iteration 6/20
# Validation: iteration 7/20
# Validation: iteration 8/20
# Validation: iteration 9/20
# Validation: iteration 10/20
# Validation: iteration 11/20
# Validation: iteration 12/20
# Validation: iteration 13/20
# Validation: iteration 14/20
# Validation: iteration 15/20
# Validation: iteration 16/20
# Validation: iteration 17/20
# Validation: iteration 18/20
# Validation: iteration 19/20
# Validation: iteration 20/20
# [NeMo I 2025-06-25 06:02:06 nemo_logging:393] Async finalization time took 0.000 s
# `Trainer.fit` stopped: `max_steps=100` reached.
# [NeMo I 2025-06-25 06:02:06 nemo_logging:393] Pending async checkpoint saves. Finalizing them synchronously now
# [NeMo I 2025-06-25 06:02:48 nemo_logging:393] Successfully saved checkpoint from iteration      99 to /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0.ckpt
# [NeMo I 2025-06-25 06:02:48 nemo_logging:393] Async checkpoint save for step 100 (/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0.ckpt) finalized successfully.
# [NeMo I 2025-06-25 06:02:48 nemo_logging:393] Successfully saved checkpoint from iteration      99 to /workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0-last.ckpt
# [NeMo I 2025-06-25 06:02:48 nemo_logging:393] Async checkpoint save for step 100 (/workspaces/bionemo-framework/sub-packages/bionemo-evo2/examples/pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=3200.0-last.ckpt) finalized successfully.
# [NeMo I 2025-06-25 06:02:50 nemo_logging:393] Async finalization time took 43.812 s

# %% [markdown]
# The plotting code is hidden in documentation for brevity. You can view the notebook on github, run it in jupyter-lab or launch the tutorial on brev.dev if you want to view the source.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorboard.backend.event_processing.event_accumulator as event_accumulator


# Function to extract data from TensorBoard event files and convert to DataFrame
def tensorboard_to_dataframe(event_file):
    """Given a TensorBoard event file, return a pandas DataFrame with the training metrics."""
    # Load the event file
    ea = event_accumulator.EventAccumulator(
        event_file,
        size_guidance={
            event_accumulator.SCALARS: 0,  # 0 means load all
        },
    )
    ea.Reload()

    # Get list of all available tags
    tags = ea.Tags()["scalars"]

    # First, find the union of all steps
    all_steps = set()
    for tag in tags:
        events = ea.Scalars(tag)
        steps = [event.step for event in events]
        all_steps.update(steps)

    # Sort steps for proper ordering
    all_steps = sorted(all_steps)

    # Initialize the dataframe with steps
    df = pd.DataFrame({"step": all_steps})

    # Add each metric as a column
    for tag in tags:
        events = ea.Scalars(tag)
        # Create a dictionary mapping steps to values
        step_to_value = {event.step: event.value for event in events}
        # Add the values to the dataframe, using NaN for missing steps
        df[tag] = df["step"].map(step_to_value)

    return df


# Example of creating a multi-metric plot with seaborn
def plot_multiple_training_metrics(df, metrics_to_plot, figsize=(15, 10)):
    """Given a pandas DataFrame with the training metrics, plot the metrics."""
    n = len(metrics_to_plot)
    fig, axes = plt.subplots(n, 1, figsize=figsize, sharex=True)

    if n == 1:  # Handle the case of a single plot
        axes = [axes]

    sns.set_style("whitegrid")

    for i, metric in enumerate(metrics_to_plot):
        if metric in df.columns:
            sns.lineplot(x="step", y=metric, data=df, ax=axes[i], linewidth=2.5, errorbar="sd")
            axes[i].set_title(metric, fontsize=14)
            axes[i].set_ylabel("Value", fontsize=12)
    axes[-1].set_xlabel("Steps", fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# The following figures show various training metrics per step.
# * `reduced_train_loss` captures the training loss. On larger runs you want to see the loss drop to about 1.08 consistently
#   for the 1b checkpoint.
# * `lr` shows the learning rate schedule for training. Typically we do a linear warmup schedule followed by an cosine decay.
#   this small notebook tutorial just goes through the initial warmup period.
# * `grad_norm` shows the gradient norm of the full model. As the model fits the data better you should see this value drop
#   down below 1.0 consistently.
# * `val_loss` shows the same kind of loss shown in `reduced_train_loss` but for a held-out set of validation samples. If you
#   ever train the model a very long time and see this start to go up while the training loss continues to drop that's a sign
#   of over-fitting. We have not yet seen this happen. Small fluctuations up and down are expected during training.

# %%
# Get the TensorBoard event file for the training run
log_dirs = !find pretraining_demo/evo2/dev -name "events.out.tfevents*"
tf_event_file = log_dirs[0]

# Extract data from your event file
df = tensorboard_to_dataframe(tf_event_file)
# You can uncomment and modify this to plot multiple metrics once you see what's available
plot_multiple_training_metrics(df, ["reduced_train_loss", "lr", "grad_norm", "val_loss"])

# %% [markdown]
# Now you have a checkpoint that you can try out in place of the converted evo2 checkpoint in the BRCA-1 tutorial
# (the path is displayed in the next code cell). To test your checkpoint, please supply the following path to the saved
# checkpoint produced by this notebook as the `--ckpt-dir {checkpoint_path}`
# argument to the `predict_evo2` command in the zero shot BRCA tutorial. For the 1b checkpoint you should see AUC above
# 0.73 if you successfully fine-tuned the checkpoint for your hardware, or to check that your hardware works with the
# converted checkpoint from hugging face as is.
#
# In our experience running this notebook for up to an hour on a single GPU is not sufficient to recover BF16 accuracy. We
# have more details about what did work in the Next Steps section below.

# %%
final_ckpt_paths = !ls -d pretraining_demo/evo2/checkpoints/*-last
final_ckpt_path = final_ckpt_paths[-1]
final_ckpt_path
# Out:
# 'pretraining_demo/evo2/checkpoints/epoch=0-step=99-consumed_samples=800.0-last'

# %% [markdown]
# ### Next steps
# On a small number of devices, or with the small demo fasta we provided in this tutorial, it's possible you are not at the needed
# 1.08 loss level to get good downstream accuracy out of this checkpoint. You can try increasing the `MAX_STEPS` parameter in the training cell,
# or running a larger cluster with more GPUs. The following loss curve was generated with a global batch size of 256 at 8192 context or approximately
# 2 million tokens per step. With that configuration we see a good loss of 1.08 after approximately 100 steps. The following figure shows our
# learning rate across the first 500 steps of fine-tuning with a global batch size of 256. Later on in this notebook we also show the slurm script
# to replicate this on your cluster.

# %%
# Display the example loss curve from a larger training run
from IPython.display import Image, display


# Load and display the image
display(Image("../assets/1b_finetuning_train_curve_500_steps_256gbs.png", width=800))

# %% [markdown]
# #### How we fine-tuned the 1b checkpoint for bf16 accuracy
# An example of the full slurm script to run the above training curve on our infrastructure is as follows:
#
# First make a `~/.netrc` file with your wandb login info. You can also accomplish this by setting wandb ENV variables,
# assuming you want to log to wandb. If not you can pass the `--no-wandb` argument as part of the args to `train_evo2`:
#
# ```ini
# machine api.wandb.ai
#   login user
#   password PASSWORD_HERE
# ```
#
# Next, paste/edit the following sbatch script for your own configuration:
#
# ```bash
# # TODO: You may need to add more SBATCH configuration here specific to your cluster.
# #SBATCH --nodes=4                       # number of nodes
# #SBATCH --gpus-per-node=8
# #SBATCH --ntasks-per-node=8                 # n tasks per machine (one task per gpu) <required>
# #SBATCH --time=04:00:00                     # wall time  (8 for batch, backfill, 2 for batch_short)
# #SBATCH --mem=0                             # all mem avail
# #SBATCH --exclusive
# set -x
# # You may want to edit this file and/or add your own version to your mounts.
# CONFIG_PATH_IN_CONTAINER=/workspace/bionemo2/sub-packages/bionemo-evo2/examples/configs/full_pretrain_shortphase_config.yaml
# # You can build a `.sqsh` file with enroot which may be faster to load on each node rather than pulling down from NGC
# IMAGE_PATH=nvcr.io/nvidia/clara/bionemo-framework:nightly
# WANDB_PROJECT_NAME= # Set you wandb project here, or leave blank and add --no-wandb to the image
# MODEL_SIZE=1b  # change this to 7b_arc_longcontext etc. This version is different.
# CP_SIZE=1
# TP_SIZE=1
# PP_SIZE=1
# MICRO_BATCH_SIZE=8
# GRAD_ACC_BATCHES=1
# SEQ_LEN=8192
# MAX_STEPS=580000 # 8T tokens given 1024 nodes and 8192 seq length
# VAL_CHECK=500
# CLIP_GRAD=250  # Arc trained without gradient clipping. Set to a large value so megatron still logs grad_norm.
# # The following arguments will remove the EOD/PAD tokens from the loss, unlike how the original Evo2 model was trained.
# #  this does not impact downstream accuracy in our experience and is more standard.
# EXTRA_ARGS="--enable-preemption --ckpt-async-save --overlap-grad-reduce --clip-grad $CLIP_GRAD --eod-pad-in-loss-mask"
# LR=0.000015
# MIN_LR=0.0000015
# WU_STEPS=100
# SEED=1234
# WD=0.001
# ADO=0.01
# HDO=0.01
# EXPERIMENT_NAME=fine_tune_evo2_1b_on_bf16
# # NCCL performance parameters
# # =========================
# export TORCH_NCCL_AVOID_RECORD_STREAMS=1
#
# # Mounts
# # =========================
# DATA_PATH= # PATH to the directory that stores your data that you want to mount into the container
# DATA_MOUNT=/workspace/bionemo2/data  # or if you configure your data with a different base dir in the config, use that here
# RESULTS_PATH_CLUSTER= # Where do you want the results to land on your shared cluster storage
# RESULTS_PATH_IMAGE=/results/
# CKPT_MOUNT_CLUSTER= # Path to shared location on your cluster where the checkpoint files can be found
# CKPT_MOUNT_IMAGE=/checkpoints/  # pragma: allowlist secret  (for some reason this line flags a high entropy string check in CI)
# NETRC_PATH=$HOME/.netrc
# NETRC_MOUNT=/root/.netrc
# # TODO either move your config to one of the mounted paths or add your own mount to a location with your configs
#
# mkdir -p $RESULTS_PATH_CLUSTER
# MOUNTS=${DATA_PATH}:${DATA_MOUNT},${RESULTS_PATH_CLUSTER}:${RESULTS_PATH_IMAGE},${NETRC_PATH}:${NETRC_MOUNT},${CKPT_MOUNT_CLUSTER}:${CKPT_MOUNT_IMAGE},$HOME/.cache:/root/.cache
# # Generate (or retrieve) a unique, shared ID per run to handle restarts in W&B and Tensorboard
# # =========================
# mkdir -p ${RESULTS_PATH_CLUSTER}
# if [ -f ${RESULTS_PATH_CLUSTER}/run.id ];
# then
#     RUN_ID=$(<${RESULTS_PATH_CLUSTER}/run.id)
# else
#     array=()
#     for i in {a..z} {A..Z} {0..9};
#     do
#     array[$RANDOM]=$i
#     done
#     RUN_ID=$(printf %s ${array[@]::8})
#     echo $RUN_ID > ${RESULTS_PATH_CLUSTER}/run.id
# fi
# # =========================
# read -r -d '' COMMAND <<EOF
# echo "*******STARTING********" \
# && echo "---------------" \
# && echo "Starting training" \
# &&  \
# train_evo2 \
#     -d $CONFIG_PATH_IN_CONTAINER \
#     --num-nodes=${SLURM_JOB_NUM_NODES} \
#     --ckpt-dir $CKPT_MOUNT_IMAGE/nemo2_evo2_1b_8k \
#     --devices=${SLURM_NTASKS_PER_NODE} \
#     --grad-acc-batches $GRAD_ACC_BATCHES \
#     --max-steps=$MAX_STEPS \
#     --seed $SEED \
#     ${EXTRA_ARGS} \
#     --wandb-run-id $RUN_ID \
#     --wandb-project $WANDB_PROJECT_NAME \
#     --lr $LR \
#     --wd $WD \
#     --activation-checkpoint-recompute-num-layers 5 \
#     --min-lr $MIN_LR \
#     --warmup-steps $WU_STEPS \
#     --attention-dropout $ADO \
#     --hidden-dropout $HDO \
#     --limit-val-batches=20 \
#     --val-check-interval=${VAL_CHECK} \
#     --result-dir=$RESULTS_PATH_IMAGE \
#     --seq-length=${SEQ_LEN} \
#     --tensor-parallel-size=${TP_SIZE} \
#     --context-parallel-size=${CP_SIZE} \
#     --pipeline-model-parallel-size=${PP_SIZE} \
#     --workers 8 \
#     --micro-batch-size=${MICRO_BATCH_SIZE} \
#     --model-size=${MODEL_SIZE}
# EOF
# srun \
#     --output ${RESULTS_PATH_CLUSTER}/slurm-%j.out \
#     --error ${RESULTS_PATH_CLUSTER}/error-%j.out \
#     --container-image=$IMAGE_PATH \
#     --container-mounts ${MOUNTS} \
#     bash -c "${COMMAND}"
# set +x
#
# ```
